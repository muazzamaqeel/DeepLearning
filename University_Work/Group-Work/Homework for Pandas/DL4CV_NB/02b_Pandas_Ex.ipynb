# %% [markdown]
# ## Exercise for Pandas
# <div style="font-size: 20px">
#   Created by:
#   Muazzam Bin Aqeel & Wesley dos santos Barisch
# </div>
#
# ---
# Instructions are given in <span style="color:blue">blue</span> color.

# %%
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# As you have learned, pandas offers many ways to load data from various sources into `DataFrames`. One especially handy way of doing so is by reading data directly from the clipboard. In this exercise, you will make use of this convenient functionality.

# %% [markdown]
# * <div style="color:blue"><a href="https://docs.google.com/spreadsheets/d/1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms/edit#gid=0">This link</a> will lead you to an example Google Sheets spreadsheet, which contains data about American high school students. Select all data (including the header row) and copy it to your clipboard.</div>
# * <div style="color:blue">Create a DataFrame object from the contents of your clipboard by calling the appropriate function. Consult <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html">the pandas documentation</a> for help.</div>
# * <div style="color:blue">Output the contents of your DataFrame. The results should look similar to this:<br><img src="./img/Students.png" width="500"/></div>

# %%
# Your solution goes here:
df = pd.read_clipboard()
styled_df = df.style.set_table_styles(
    [{'selector': 'th',
      'props': [('font-weight', 'bold')]}]
)
styled_df
# Out:
# <style type="text/css">
# #T_c09f0 th {
#   font-weight: bold;
# }
# </style>
# <table id="T_c09f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c09f0_level0_col0" class="col_heading level0 col0" >Student Name</th>
#       <th id="T_c09f0_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_c09f0_level0_col2" class="col_heading level0 col2" >Class Level</th>
#       <th id="T_c09f0_level0_col3" class="col_heading level0 col3" >Home State</th>
#       <th id="T_c09f0_level0_col4" class="col_heading level0 col4" >Major</th>
#       <th id="T_c09f0_level0_col5" class="col_heading level0 col5" >Extracurricular Activity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c09f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c09f0_row0_col0" class="data row0 col0" >Alexandra</td>
#       <td id="T_c09f0_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_c09f0_row0_col2" class="data row0 col2" >4. Senior</td>
#       <td id="T_c09f0_row0_col3" class="data row0 col3" >CA</td>
#       <td id="T_c09f0_row0_col4" class="data row0 col4" >English</td>
#       <td id="T_c09f0_row0_col5" class="data row0 col5" >Drama Club</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c09f0_row1_col0" class="data row1 col0" >Andrew</td>
#       <td id="T_c09f0_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_c09f0_row1_col2" class="data row1 col2" >1. Freshman</td>
#       <td id="T_c09f0_row1_col3" class="data row1 col3" >SD</td>
#       <td id="T_c09f0_row1_col4" class="data row1 col4" >Math</td>
#       <td id="T_c09f0_row1_col5" class="data row1 col5" >Lacrosse</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c09f0_row2_col0" class="data row2 col0" >Anna</td>
#       <td id="T_c09f0_row2_col1" class="data row2 col1" >Female</td>
#       <td id="T_c09f0_row2_col2" class="data row2 col2" >1. Freshman</td>
#       <td id="T_c09f0_row2_col3" class="data row2 col3" >NC</td>
#       <td id="T_c09f0_row2_col4" class="data row2 col4" >English</td>
#       <td id="T_c09f0_row2_col5" class="data row2 col5" >Basketball</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c09f0_row3_col0" class="data row3 col0" >Becky</td>
#       <td id="T_c09f0_row3_col1" class="data row3 col1" >Female</td>
#       <td id="T_c09f0_row3_col2" class="data row3 col2" >2. Sophomore</td>
#       <td id="T_c09f0_row3_col3" class="data row3 col3" >SD</td>
#       <td id="T_c09f0_row3_col4" class="data row3 col4" >Art</td>
#       <td id="T_c09f0_row3_col5" class="data row3 col5" >Baseball</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c09f0_row4_col0" class="data row4 col0" >Benjamin</td>
#       <td id="T_c09f0_row4_col1" class="data row4 col1" >Male</td>
#       <td id="T_c09f0_row4_col2" class="data row4 col2" >4. Senior</td>
#       <td id="T_c09f0_row4_col3" class="data row4 col3" >WI</td>
#       <td id="T_c09f0_row4_col4" class="data row4 col4" >English</td>
#       <td id="T_c09f0_row4_col5" class="data row4 col5" >Basketball</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c09f0_row5_col0" class="data row5 col0" >Carl</td>
#       <td id="T_c09f0_row5_col1" class="data row5 col1" >Male</td>
#       <td id="T_c09f0_row5_col2" class="data row5 col2" >3. Junior</td>
#       <td id="T_c09f0_row5_col3" class="data row5 col3" >MD</td>
#       <td id="T_c09f0_row5_col4" class="data row5 col4" >Art</td>
#       <td id="T_c09f0_row5_col5" class="data row5 col5" >Debate</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c09f0_row6_col0" class="data row6 col0" >Carrie</td>
#       <td id="T_c09f0_row6_col1" class="data row6 col1" >Female</td>
#       <td id="T_c09f0_row6_col2" class="data row6 col2" >3. Junior</td>
#       <td id="T_c09f0_row6_col3" class="data row6 col3" >NE</td>
#       <td id="T_c09f0_row6_col4" class="data row6 col4" >English</td>
#       <td id="T_c09f0_row6_col5" class="data row6 col5" >Track & Field</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c09f0_row7_col0" class="data row7 col0" >Dorothy</td>
#       <td id="T_c09f0_row7_col1" class="data row7 col1" >Female</td>
#       <td id="T_c09f0_row7_col2" class="data row7 col2" >4. Senior</td>
#       <td id="T_c09f0_row7_col3" class="data row7 col3" >MD</td>
#       <td id="T_c09f0_row7_col4" class="data row7 col4" >Math</td>
#       <td id="T_c09f0_row7_col5" class="data row7 col5" >Lacrosse</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c09f0_row8_col0" class="data row8 col0" >Dylan</td>
#       <td id="T_c09f0_row8_col1" class="data row8 col1" >Male</td>
#       <td id="T_c09f0_row8_col2" class="data row8 col2" >1. Freshman</td>
#       <td id="T_c09f0_row8_col3" class="data row8 col3" >MA</td>
#       <td id="T_c09f0_row8_col4" class="data row8 col4" >Math</td>
#       <td id="T_c09f0_row8_col5" class="data row8 col5" >Baseball</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c09f0_row9_col0" class="data row9 col0" >Edward</td>
#       <td id="T_c09f0_row9_col1" class="data row9 col1" >Male</td>
#       <td id="T_c09f0_row9_col2" class="data row9 col2" >3. Junior</td>
#       <td id="T_c09f0_row9_col3" class="data row9 col3" >FL</td>
#       <td id="T_c09f0_row9_col4" class="data row9 col4" >English</td>
#       <td id="T_c09f0_row9_col5" class="data row9 col5" >Drama Club</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c09f0_row10_col0" class="data row10 col0" >Ellen</td>
#       <td id="T_c09f0_row10_col1" class="data row10 col1" >Female</td>
#       <td id="T_c09f0_row10_col2" class="data row10 col2" >1. Freshman</td>
#       <td id="T_c09f0_row10_col3" class="data row10 col3" >WI</td>
#       <td id="T_c09f0_row10_col4" class="data row10 col4" >Physics</td>
#       <td id="T_c09f0_row10_col5" class="data row10 col5" >Drama Club</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c09f0_row11_col0" class="data row11 col0" >Fiona</td>
#       <td id="T_c09f0_row11_col1" class="data row11 col1" >Female</td>
#       <td id="T_c09f0_row11_col2" class="data row11 col2" >1. Freshman</td>
#       <td id="T_c09f0_row11_col3" class="data row11 col3" >MA</td>
#       <td id="T_c09f0_row11_col4" class="data row11 col4" >Art</td>
#       <td id="T_c09f0_row11_col5" class="data row11 col5" >Debate</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c09f0_row12_col0" class="data row12 col0" >John</td>
#       <td id="T_c09f0_row12_col1" class="data row12 col1" >Male</td>
#       <td id="T_c09f0_row12_col2" class="data row12 col2" >3. Junior</td>
#       <td id="T_c09f0_row12_col3" class="data row12 col3" >CA</td>
#       <td id="T_c09f0_row12_col4" class="data row12 col4" >Physics</td>
#       <td id="T_c09f0_row12_col5" class="data row12 col5" >Basketball</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c09f0_row13_col0" class="data row13 col0" >Jonathan</td>
#       <td id="T_c09f0_row13_col1" class="data row13 col1" >Male</td>
#       <td id="T_c09f0_row13_col2" class="data row13 col2" >2. Sophomore</td>
#       <td id="T_c09f0_row13_col3" class="data row13 col3" >SC</td>
#       <td id="T_c09f0_row13_col4" class="data row13 col4" >Math</td>
#       <td id="T_c09f0_row13_col5" class="data row13 col5" >Debate</td>
#     </tr>
#     <tr>
#       <th id="T_c09f0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c09f0_row14_c

# %% [markdown]
# As you can see, the **`Home State`** Column makes use of state name abbreviations. We should find out what these abbreviations actually stand for.
#
# * <div style="color:blue"><a href="https://www.50states.com/abbreviations.htm">This online resource</a> lists all state abbreviations in conjunction with their respective full state names. Select the contents of the table (up until Wyoming is sufficient) and copy them to your clipboard. However, do not copy the header row this time around.</div>
# * <div style="color:blue">Create a second DataFrame object from the contents of your clipboard and provide proper column names while doing so.</div>
# * <div style="color:blue">Output the contents of your DataFrame. The results should look similar to this:<br><img src="./img/States.png" width="200"/></div>

# %%
# Your solution goes here:

state_df = pd.read_clipboard(header=None)
state_df.columns = ['State', 'State_abbr', 'State_code']
styled_df = state_df.style.set_table_styles(
    [{'selector': 'th', 'props': [('font-weight', 'bold')]}]
)
styled_df
# Out:
# <style type="text/css">
# #T_0f883 th {
#   font-weight: bold;
# }
# </style>
# <table id="T_0f883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f883_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_0f883_level0_col1" class="col_heading level0 col1" >State_abbr</th>
#       <th id="T_0f883_level0_col2" class="col_heading level0 col2" >State_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f883_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f883_row0_col0" class="data row0 col0" >US STATE</td>
#       <td id="T_0f883_row0_col1" class="data row0 col1" >POSTAL ABBREVIATION</td>
#       <td id="T_0f883_row0_col2" class="data row0 col2" >STANDARD ABBREVIATION</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f883_row1_col0" class="data row1 col0" >Alabama</td>
#       <td id="T_0f883_row1_col1" class="data row1 col1" >AL</td>
#       <td id="T_0f883_row1_col2" class="data row1 col2" >Ala.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f883_row2_col0" class="data row2 col0" >Alaska</td>
#       <td id="T_0f883_row2_col1" class="data row2 col1" >AK</td>
#       <td id="T_0f883_row2_col2" class="data row2 col2" >Alaska</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f883_row3_col0" class="data row3 col0" >Arizona</td>
#       <td id="T_0f883_row3_col1" class="data row3 col1" >AZ</td>
#       <td id="T_0f883_row3_col2" class="data row3 col2" >Ariz.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f883_row4_col0" class="data row4 col0" >Arkansas</td>
#       <td id="T_0f883_row4_col1" class="data row4 col1" >AR</td>
#       <td id="T_0f883_row4_col2" class="data row4 col2" >Ark.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0f883_row5_col0" class="data row5 col0" >California</td>
#       <td id="T_0f883_row5_col1" class="data row5 col1" >CA</td>
#       <td id="T_0f883_row5_col2" class="data row5 col2" >Calif.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0f883_row6_col0" class="data row6 col0" >Colorado</td>
#       <td id="T_0f883_row6_col1" class="data row6 col1" >CO</td>
#       <td id="T_0f883_row6_col2" class="data row6 col2" >Color.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0f883_row7_col0" class="data row7 col0" >Connecticut</td>
#       <td id="T_0f883_row7_col1" class="data row7 col1" >CT</td>
#       <td id="T_0f883_row7_col2" class="data row7 col2" >Conn.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0f883_row8_col0" class="data row8 col0" >Delaware</td>
#       <td id="T_0f883_row8_col1" class="data row8 col1" >DE</td>
#       <td id="T_0f883_row8_col2" class="data row8 col2" >Del.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0f883_row9_col0" class="data row9 col0" >Florida</td>
#       <td id="T_0f883_row9_col1" class="data row9 col1" >FL</td>
#       <td id="T_0f883_row9_col2" class="data row9 col2" >Fla.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0f883_row10_col0" class="data row10 col0" >Georgia</td>
#       <td id="T_0f883_row10_col1" class="data row10 col1" >GA</td>
#       <td id="T_0f883_row10_col2" class="data row10 col2" >Ga.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0f883_row11_col0" class="data row11 col0" >Hawaii</td>
#       <td id="T_0f883_row11_col1" class="data row11 col1" >HI</td>
#       <td id="T_0f883_row11_col2" class="data row11 col2" >Hawaii</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0f883_row12_col0" class="data row12 col0" >Idaho</td>
#       <td id="T_0f883_row12_col1" class="data row12 col1" >ID</td>
#       <td id="T_0f883_row12_col2" class="data row12 col2" >Idaho</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0f883_row13_col0" class="data row13 col0" >Illinois</td>
#       <td id="T_0f883_row13_col1" class="data row13 col1" >IL</td>
#       <td id="T_0f883_row13_col2" class="data row13 col2" >Ill.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0f883_row14_col0" class="data row14 col0" >Indiana</td>
#       <td id="T_0f883_row14_col1" class="data row14 col1" >IN</td>
#       <td id="T_0f883_row14_col2" class="data row14 col2" >Ind.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0f883_row15_col0" class="data row15 col0" >Iowa</td>
#       <td id="T_0f883_row15_col1" class="data row15 col1" >IA</td>
#       <td id="T_0f883_row15_col2" class="data row15 col2" >Iowa</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0f883_row16_col0" class="data row16 col0" >Kansas</td>
#       <td id="T_0f883_row16_col1" class="data row16 col1" >KS</td>
#       <td id="T_0f883_row16_col2" class="data row16 col2" >Kan.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0f883_row17_col0" class="data row17 col0" >Kentucky</td>
#       <td id="T_0f883_row17_col1" class="data row17 col1" >KY</td>
#       <td id="T_0f883_row17_col2" class="data row17 col2" >Ky.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0f883_row18_col0" class="data row18 col0" >Louisiana</td>
#       <td id="T_0f883_row18_col1" class="data row18 col1" >LA</td>
#       <td id="T_0f883_row18_col2" class="data row18 col2" >La.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0f883_row19_col0" class="data row19 col0" >Maine</td>
#       <td id="T_0f883_row19_col1" class="data row19 col1" >ME</td>
#       <td id="T_0f883_row19_col2" class="data row19 col2" >Maine</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0f883_row20_col0" class="data row20 col0" >Maryland</td>
#       <td id="T_0f883_row20_col1" class="data row20 col1" >MD</td>
#       <td id="T_0f883_row20_col2" class="data row20 col2" >Md.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0f883_row21_col0" class="data row21 col0" >Massachusetts</td>
#       <td id="T_0f883_row21_col1" class="data row21 col1" >MA</td>
#       <td id="T_0f883_row21_col2" class="data row21 col2" >Mass.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0f883_row22_col0" class="data row22 col0" >Michigan</td>
#       <td id="T_0f883_row22_col1" class="data row22 col1" >MI</td>
#       <td id="T_0f883_row22_col2" class="data row22 col2" >Mich.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0f883_row23_col0" class="data row23 col0" >Minnesota</td>
#       <td id="T_0f883_row23_col1" class="data row23 col1" >MN</td>
#       <td id="T_0f883_row23_col2" class="data row23 col2" >Minn.</td>
#     </tr>
#     <tr>
#       <th id="T_0f883_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_0f883_row24_col0" class="data row24 col0" >Mississippi</td>
#       <td id="T_0f883_row24_col1" class="data row24 col1" >MS</td>
#       <td id="T_0f883_row24_col2" class="data ro

# %% [markdown]
# Now that we have our student information and the accompanying state name information, it would be nice to combine both into a single `DataFrame`.
#
# * <div style="color:blue">Look online for ways to <b>merge</b> or <b>join</b> two DataFrames on specific columns.</div>
# * <div style="color:blue">Create a final DataFrame which holds the combined information. Your results should look something like this:</div><br><img src="./img/Merge.png" width="500"/></div>

# %%
merged_df = pd.merge(df, state_df, left_on='Home State', right_on='State_abbr')
merged_df
# Out:
#    Student Name  Gender   Class Level Home State    Major  \
# 0     Alexandra  Female     4. Senior         CA  English
# 1          John    Male     3. Junior         CA  Physics
# 2       Maureen  Female   1. Freshman         CA  Physics
# 3        Robert    Male   1. Freshman         CA  English
# 4        Andrew    Male   1. Freshman         SD     Math
# 5         Becky  Female  2. Sophomore         SD      Art
# 6          Anna  Female   1. Freshman         NC  English
# 7        Olivia  Female     4. Senior         NC  Physics
# 8      Benjamin    Male     4. Senior         WI  English
# 9         Ellen  Female   1. Freshman         WI  Physics
# 10         Carl    Male     3. Junior         MD      Art
# 11      Dorothy  Female     4. Senior         MD     Math
# 12       Carrie  Female     3. Junior         NE  English
# 13        Kevin    Male  2. Sophomore         NE  Physics
# 14        Dylan    Male   1. Freshman         MA     Math
# 15        Fiona  Female   1. Freshman         MA      Art
# 16       Edward    Male     3. Junior         FL  English
# 17         Will    Male     4. Senior         FL     Math
# 18     Jonathan    Male  2. Sophomore         SC     Math
# 19         Lisa  Female     3. Junior         SC      Art
# 20       Joseph    Male   1. Freshman         AK  English
# 21         Mary  Female  2. Sophomore         AK  Physics
# 22    Josephine  Female   1. Freshman         NY     Math
# 23         Nick    Male     4. Senior         NY      Art
# 24      Patrick    Male   1. Freshman         NY      Art
# 25        Stacy  Female   1. Freshman         NY     Math
# 26        Karen  Female  2. Sophomore         NH  English
# 27         Sean    Male   1. Freshman         NH  Physics
# 28       Pamela  Female     3. Junior         RI     Math
# 29       Thomas    Male  2. Sophomore         RI      Art
#
#    Extracurricular Activity           State State_abbr State_code
# 0                Drama Club      California         CA     Calif.
# 1                Basketball      California         CA     Calif.
# 2                Basketball      California         CA     Calif.
# 3             Track & Field      California         CA     Calif.
# 4                  Lacrosse    South Dakota         SD     S.Dak.
# 5                  Baseball    South Dakota         SD     S.Dak.
# 6                Basketball  North Carolina         NC       N.C.
# 7             Track & Field  North Carolina         NC       N.C.
# 8                Basketball       Wisconsin         WI       Wis.
# 9                Drama Club       Wisconsin         WI       Wis.
# 10                   Debate        Maryland         MD        Md.
# 11                 Lacrosse        Maryland         MD        Md.
# 12            Track & Field        Nebraska         NE       Neb.
# 13               Drama Club        Nebraska         NE       Neb.
# 14                 Baseball   Massachusetts         MA      Mass.
# 15                   Debate   Massachusetts         MA      Mass.
# 16               Drama Club         Florida         FL       Fla.
# 17                   Debate         Florida         FL       Fla.
# 18                   Debate  South Carolina         SC       S.C.
# 19                 Lacrosse  South Carolina         SC       S.C.
# 20               Drama Club          Alaska         AK     Alaska
# 21            Track & Field          Alaska         AK     Alaska
# 22                   Debate        New York         NY       N.Y.
# 23                 Baseball        New York         NY       N.Y.
# 24                 Lacrosse        New York         NY       N.Y.
# 25                 Baseball        New York         NY       N.Y.
# 26               Basketball   New Hampshire         NH       N.H.
# 27            Track & Field   New Hampshire         NH       N.H.
# 28                 Baseball    Rhode Island         RI       R.I.
# 29                 Lacrosse    Rhode Island         RI       R.I.
